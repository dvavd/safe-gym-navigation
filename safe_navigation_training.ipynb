# %%
import omnisafe
from gym_navigation.envs.navigation_track_safe import NavigationTrackSafe


custom_cfgs = {
    'model_cfgs': {
        'actor_type': 'gaussian_learning'
    },
    'train_cfgs': {
        'total_steps': 1024000,
        'vector_env_nums': 1,
        'parallel': 1,
    },
    'algo_cfgs': {
        'steps_per_epoch': 2048,
        'update_iters': 1,
    },
    'logger_cfgs': {
        'use_wandb': False,
    },
}

env_id = 'NavigationTrackSafe-v0'
agent = omnisafe.Agent('PPOLag', env_id, custom_cfgs=custom_cfgs)
agent.learn()
# Out:
# Loading PPOLag.yaml from /Users/davidstreuli/anaconda3/envs/omnisafe/lib/python3.10/site-packages/omnisafe/utils/../configs/on-policy/PPOLag.yaml
# Logging data to ./runs/PPOLag-{NavigationTrackSafe-v0}/seed-000-2025-05-02-17-15-55/progress.csv
# Save with config in config.json
# INFO: Start training
# /Users/davidstreuli/anaconda3/envs/omnisafe/lib/python3.10/site-packages/rich/live.py:231: UserWarning: install
# "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# Warning: trajectory cut off when rollout by epoch at 107.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                        ┃ Value                  ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                  │ 122.58707427978516     │
# │ Metrics/EpCost                 │ 54.35714340209961      │
# │ Metrics/EpLen                  │ 138.64285278320312     │
# │ Train/Epoch                    │ 0.0                    │
# │ Train/Entropy                  │ 1.4187657833099365     │
# │ Train/KL                       │ 0.004898553714156151   │
# │ Train/StopIter                 │ 1.0                    │
# │ Train/PolicyRatio/Mean         │ 1.0028104782104492     │
# │ Train/PolicyRatio/Min          │ 1.0028104782104492     │
# │ Train/PolicyRatio/Max          │ 1.0028104782104492     │
# │ Train/PolicyRatio/Std          │ 0.01005978137254715    │
# │ Train/LR                       │ 0.00029940000968053937 │
# │ Train/PolicyStd                │ 0.9998273849487305     │
# │ TotalEnvSteps                  │ 2048.0                 │
# │ Loss/Loss_pi                   │ 0.0015056068077683449  │
# │ Loss/Loss_pi/Delta             │ 0.0015056068077683449  │
# │ Value/Adv                      │ 0.15676826238632202    │
# │ Loss/Loss_reward_critic        │ 2788.071533203125      │
# │ Loss/Loss_reward_critic/Delta  │ 2788.071533203125      │
# │ Value/reward                   │ -0.04310157895088196   │
# │ Loss/Loss_cost_critic          │ 73.964599609375        │
# │ Loss/Loss_cost_critic/Delta    │ 73.964599609375        │
# │ Value/cost                     │ -0.013164207339286804  │
# │ Time/Total                     │ 1.2278211116790771     │
# │ Time/Rollout                   │ 1.1142141819000244     │
# │ Time/Update                    │ 0.11300110816955566    │
# │ Time/Epoch                     │ 1.2272393703460693     │
# │ Time/FPS                       │ 1668.7877197265625     │
# │ Metrics/LagrangeMultiplier/Mea │ 0.03599999472498894    │
# │ Metrics/LagrangeMultiplier/Min │ 0.03599999472498894    │
# │ Metrics/LagrangeMultiplier/Max │ 0.03599999472498894    │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                    │
# └────────────────────────────────┴────────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 41.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                        ┃ Value                  ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                  │ 144.65191650390625     │
# │ Metrics/EpCost                 │ 47.925926208496094     │
# │ Metrics/EpLen                  │ 146.22222900390625     │
# │ Train/Epoch                    │ 1.0                    │
# │ Train/Entropy                  │ 1.4190795421600342     │
# │ Train/KL                       │ 0.014152418822050095   │
# │ Train/StopIter                 │ 1.0                    │
# │ Train/PolicyRatio/Mean         │ 1.0006388425827026     │
# │ Train/PolicyRatio/Min          │ 1.0006388425827026     │
# │ Train/PolicyRatio/Max          │ 1.0006388425827026     │
# │ Train/PolicyRatio/Std          │ 0.010650880634784698   │
# │ Train/LR                       │ 0.00029880000511184335 │
# │ Train/PolicyStd                │ 1.0001431703567505     │
# │ TotalEnvSteps                  │ 4096.0                 │
# │ Loss/Loss_pi                   │ -0.005050577223300934  │
# │ Loss/Loss_pi/Delta             │ -0.006556184031069279  │
# │ Value/Adv                      │ 0.14962175488471985    │
# │ Loss/Loss_reward_critic        │ 2846.4755859375        │
# │ Loss/Loss_reward_critic/Delta  │ 58.404052734375        │
# │ Value/reward                   │ 0.3443276882171631     │
# │ Loss/Loss_cost_critic          │ 36.71421432495117      │
# │ Loss/Loss_cost_critic/Delta    │ -37.25038528442383     │
# │ Value/cost                     │ 0.37686875462532043    │
# │ Time/Total                     │ 2.4978487491607666     │
# │ Time/Rollout                   │ 1.1192572116851807     │
# │ Time/Update                    │ 0.14197492599487305    │
# │ Time/Epoch                     │ 1.2612559795379639     │
# │ Time/FPS                       │ 1623.7781982421875     │
# │ Metrics/LagrangeMultiplier/Mea │ 0.07051536440849304    │
# │ Metrics/LagrangeMultiplier/Min │ 0.07051536440849304    │
# │ Metrics/LagrangeMultiplier/Max │ 0.07051536440849304    │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                    │
# └────────────────────────────────┴────────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 446.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                        ┃ Value                 ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                  │ 164.1932830810547     │
# │ Metrics/EpCost                 │ 49.18918991088867     │
# │ Metrics/EpLen                  │ 150.0                 │
# │ Train/Epoch                    │ 2.0                   │
# │ Train/Entropy                  │ 1.4203181266784668    │
# │ Train/KL                       │ 0.005422117188572884  │
# │ Train/StopIter                 │ 1.0                   │
# │ Train/PolicyRatio/Mean         │ 0.997585654258728     │
# │ Train/PolicyRatio/Min          │ 0.997585654258728     │
# │ Train/PolicyRatio/Max          │ 0.997585654258728     │
# │ Train/PolicyRatio/Std          │ 0.012043142691254616  │
# │ Train/LR                       │ 0.0002982000005431473 │
# │ Train/PolicyStd                │ 1.0013829469680786    │
# │ TotalEnvSteps                  │ 6144.0                │
# │ Loss/Loss_pi                   │ -0.001574990339577198 │
# │ Loss/Loss_pi/Delta             │ 0.003475586883723736  │
# │ Value/Adv                      │ -0.061102308332920074 │
# │ Loss/Loss_reward_critic        │ 2642.822509765625     │
# │ Loss/Loss_reward_critic/Delta  │ -203.653076171875     │
# │ Value/reward                   │ 0.8959865570068359    │
# │ Loss/Loss_cost_critic          │ 43.069915771484375    │
# │ Loss/Loss_cost_critic/Delta    │ 6.355701446533203     │
# │ Value/cost                     │ 0.7693408727645874    │
# │ Time/Total                     │ 3.7167978286743164    │
# │ Time/Rollout                   │ 1.1139709949493408    │
# │ Time/Update                    │ 0.09653711318969727   │
# │ Time/Epoch                     │ 1.2105309963226318    │
# │ Time/FPS                       │ 1691.8209228515625    │
# │ Metrics/LagrangeMultiplier/Mea │ 0.1050703376531601    │
# │ Metrics/LagrangeMultiplier/Min │ 0.1050703376531601    │
# │ Metrics/LagrangeMultiplier/Max │ 0.1050703376531601    │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                   │
# └────────────────────────────────┴───────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 198.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                        ┃ Value                  ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                  │ 243.82286071777344     │
# │ Metrics/EpCost                 │ 51.70731735229492      │
# │ Metrics/EpLen                  │ 180.48780822753906     │
# │ Train/Epoch                    │ 3.0                    │
# │ Train/Entropy                  │ 1.4203780889511108     │
# │ Train/KL                       │ 0.009599097073078156   │
# │ Train/StopIter                 │ 1.0                    │
# │ Train/PolicyRatio/Mean         │ 0.9987211227416992     │
# │ Train/PolicyRatio/Min          │ 0.9987211227416992     │
# │ Train/PolicyRatio/Max          │ 0.9987211227416992     │
# │ Train/PolicyRatio/Std          │ 0.011625989340245724   │
# │ Train/LR                       │ 0.0002975999959744513  │
# │ Train/PolicyStd                │ 1.001441240310669      │
# │ TotalEnvSteps                  │ 8192.0                 │
# │ Loss/Loss_pi                   │ -0.003276440314948559  │
# │ Loss/Loss_pi/Delta             │ -0.0017014499753713608 │
# │ Value/Adv                      │ 0.011785853654146194   │
# │ Loss/Loss_reward_critic        │ 2128.445556640625      │
# │ Loss/Loss_reward_critic/Delta  │ -514.376953125         │
# │ Value/reward                   │ 1.6716771125793457     │
# │ Loss/Loss_cost_critic          │ 31.864261627197266     │
# │ Loss/Loss_cost_critic/Delta    │ -11.20565414428711     │
# │ Value/cost                     │ 1.4936562776565552     │
# │ Time/Total                     │ 4.93038272857666       │
# │ Time/Rollout                   │ 1.1063010692596436     │
# │ Time/Update                    │ 0.0987558364868164     │
# │ Time/Epoch                     │ 1.2050797939300537     │
# │ Time/FPS                       │ 1699.4725341796875     │
# │ Metrics/LagrangeMultiplier/Mea │ 0.1398106962442398     │
# │ Metrics/LagrangeMultiplier/Min │ 0.1398106962442398     │
# │ Metrics/LagrangeMultiplier/Max │ 0.1398106962442398     │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                    │
# └────────────────────────────────┴────────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 2048.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                        ┃ Value                 ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                  │ 243.82286071777344    │
# │ Metrics/EpCost                 │ 51.70731735229492     │
# │ Metrics/EpLen                  │ 180.48780822753906    │
# │ Train/Epoch                    │ 4.0                   │
# │ Train/Entropy                  │ 1.4191346168518066    │
# │ Train/KL                       │ 0.018552038818597794  │
# │ Train/StopIter                 │ 1.0                   │
# │ Train/PolicyRatio/Mean         │ 1.0039055347442627    │
# │ Train/PolicyRatio/Min          │ 1.0039055347442627    │
# │ Train/PolicyRatio/Max          │ 1.0039055347442627    │
# │ Train/PolicyRatio/Std          │ 0.02250487357378006   │
# │ Train/LR                       │ 0.0002969999914057553 │
# │ Train/PolicyStd                │ 1.000197410583496     │
# │ TotalEnvSteps                  │ 10240.0               │
# │ Loss/Loss_pi                   │ -0.016167273744940758 │
# │ Loss/Loss_pi/Delta             │ -0.012890833429992199 │
# │ Value/Adv                      │ -0.00994790717959404  │
# │ Loss/Loss_reward_critic        │ 2127.8720703125       │
# │ Loss/Loss_reward_critic/Delta  │ -0.573486328125       │
# │ Value/reward                   │ 2.540646553039551     │
# │ Loss/Loss_cost_critic          │ 23.164148330688477    │
# │ Loss/Loss_cost_critic/Delta    │ -8.700113296508789    │
# │ Value/cost                     │ 2.274409770965576     │
# │ Time/Total                     │ 6.137450218200684     │
# │ Time/Rollout                   │ 1.1004338264465332    │
# │ Time/Update                    │ 0.09815597534179688   │
# │ Time/Epoch                     │ 1.198612928390503     │
# │ Time/FPS                       │ 1708.6417236328125    │
# │ Metrics/LagrangeMultiplier/Mea │ 0.1746598333120346    │
# │ Metrics/LagrangeMultiplier/Min │ 0.1746598333120346    │
# │ Metrics/LagrangeMultiplier/Max │ 0.1746598333120346    │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                   │
# └────────────────────────────────┴───────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 1953.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                        ┃ Value                  ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                  │ 240.22576904296875     │
# │ Metrics/EpCost                 │ 51.238094329833984     │
# │ Metrics/EpLen                  │ 178.45237731933594     │
# │ Train/Epoch                    │ 5.0                    │
# │ Train/Entropy                  │ 1.4173908233642578     │
# │ Train/KL                       │ 0.007478576153516769   │
# │ Train/StopIter                 │ 1.0                    │
# │ Train/PolicyRatio/Mean         │ 0.9992767572402954     │
# │ Train/PolicyRatio/Min          │ 0.9992767572402954     │
# │ Train/PolicyRatio/Max          │ 0.9992767572402954     │
# │ Train/PolicyRatio/Std          │ 0.014894561842083931   │
# │ Train/LR                       │ 0.00029639998683705926 │
# │ Train/PolicyStd                │ 0.9984558820724487     │
# │ TotalEnvSteps                  │ 12288.0                │
# │ Loss/Loss_pi                   │ -0.0014910763129591942 │
# │ Loss/Loss_pi/Delta             │ 0.014676197431981564   │
# │ Value/Adv                      │ 0.051783330738544464   │
# │ Loss/Loss_reward_critic        │ 2708.59228515625       │
# │ Loss/Loss_reward_critic/Delta  │ 580.72021484375        │
# │ Value/reward                   │ 3.6793503761291504     │
# │ Loss/Loss_cost_critic          │ 12.532207489013672     │
# │ Loss/Loss_cost_critic/Delta    │ -10.631940841674805    │
# │ Value/cost                     │ 2.7890591621398926     │
# │ Time/Total                     │ 7.387687683105469      │
# │ Time/Rollout                   │ 1.1436989307403564     │
# │ Time/Update                    │ 0.09737086296081543    │
# │ Time/Epoch                     │ 1.2411019802093506     │
# │ Time/FPS                       │ 1650.147705078125      │
# │ Metrics/LagrangeMultiplier/Mea │ 0.20955145359039307    │
# │ Metrics/LagrangeMultiplier/Min │ 0.20955145359039307    │
# │ Metrics/LagrangeMultiplier/Max │ 0.20955145359039307    │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                    │
# └────────────────────────────────┴────────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 36.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                        ┃ Value                 ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                  │ 381.1867370605469     │
# │ Metrics/EpCost                 │ 60.79069900512695     │
# │ Metrics/EpLen                  │ 221.093017578125      │
# │ Train/Epoch                    │ 6.0                   │
# │ Train/Entropy                  │ 1.4164729118347168    │
# │ Train/KL                       │ 0.008430728688836098  │
# │ Train/StopIter                 │ 1.0                   │
# │ Train/PolicyRatio/Mean         │ 1.0011316537857056    │
# │ Train/PolicyRatio/Min          │ 1.0011316537857056    │
# │ Train/PolicyRatio/Max          │ 1.0011316537857056    │
# │ Train/PolicyRatio/Std          │ 0.008161270059645176  │
# │ Train/LR                       │ 0.0002958000113721937 │
# │ Train/PolicyStd                │ 0.9975385069847107    │
# │ TotalEnvSteps                  │ 14336.0               │
# │ Loss/Loss_pi                   │ -0.005110533908009529 │
# │ Loss/Loss_pi/Delta             │ -0.003619457595050335 │
# │ Value/Adv                      │ 0.1556548923254013    │
# │ Loss/Loss_reward_critic        │ 2873.954833984375     │
# │ Loss/Loss_reward_critic/Delta  │ 165.362548828125      │
# │ Value/reward                   │ 4.285715103149414     │
# │ Loss/Loss_cost_critic          │ 39.92387771606445     │
# │ Loss/Loss_cost_critic/Delta    │ 27.39167022705078     │
# │ Value/cost                     │ 3.1818912029266357    │
# │ Time/Total                     │ 8.596002578735352     │
# │ Time/Rollout                   │ 1.1037471294403076    │
# │ Time/Update                    │ 0.09621310234069824   │
# │ Time/Epoch                     │ 1.199981927871704     │
# │ Time/FPS                       │ 1706.6923828125       │
# │ Metrics/LagrangeMultiplier/Mea │ 0.24479754269123077   │
# │ Metrics/LagrangeMultiplier/Min │ 0.24479754269123077   │
# │ Metrics/LagrangeMultiplier/Max │ 0.24479754269123077   │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                   │
# └────────────────────────────────┴───────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 1936.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                        ┃ Value                  ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                  │ 375.6859130859375      │
# │ Metrics/EpCost                 │ 59.818180084228516     │
# │ Metrics/EpLen                  │ 218.61363220214844     │
# │ Train/Epoch                    │ 7.0                    │
# │ Train/Entropy                  │ 1.4159523248672485     │
# │ Train/KL                       │ 0.007289706263691187   │
# │ Train/StopIter                 │ 1.0                    │
# │ Train/PolicyRatio/Mean         │ 0.9987449645996094     │
# │ Train/PolicyRatio/Min          │ 0.9987449645996094     │
# │ Train/PolicyRatio/Max          │ 0.9987449645996094     │
# │ Train/PolicyRatio/Std          │ 0.014522158540785313   │
# │ Train/LR                       │ 0.00029520000680349767 │
# │ Train/PolicyStd                │ 0.9970190525054932     │
# │ TotalEnvSteps                  │ 16384.0                │
# │ Loss/Loss_pi                   │ -0.0020357435569167137 │
# │ Loss/Loss_pi/Delta             │ 0.0030747903510928154  │
# │ Value/Adv                      │ -0.06612782180309296   │
# │ Loss/Loss_reward_critic        │ 2956.740234375         │
# │ Loss/Loss_reward_critic/Delta  │ 82.785400390625        │
# │ Value/reward                   │ 5.29478120803833       │
# │ Loss/Loss_cost_critic          │ 19.181005477905273     │
# │ Loss/Loss_cost_critic/Delta    │ -20.74287223815918     │
# │ Value/cost                     │ 4.232229232788086      │
# │ Time/Total                     │ 9.80113410949707       │
# │ Time/Rollout                   │ 1.099776029586792      │
# │ Time/Update                    │ 0.09662914276123047    │
# │ Time/Epoch                     │ 1.196427822113037      │
# │ Time/FPS                       │ 1711.76220703125       │
# │ Metrics/LagrangeMultiplier/Mea │ 0.2803105413913727     │
# │ Metrics/LagrangeMultiplier/Min │ 0.2803105413913727     │
# │ Metrics/LagrangeMultiplier/Max │ 0.2803105413913727     │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                    │
# └────────────────────────────────┴────────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 608.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                        ┃ Value                  ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                  │ 458.7583312988281      │
# │ Metrics/EpCost                 │ 61.41304397583008      │
# │ Metrics/EpLen                  │ 240.4130401611328      │
# │ Train/Epoch                    │ 8.0                    │
# │ Train/Entropy                  │ 1.4147014617919922     │
# │ Train/KL                       │ 0.005900113843381405   │
# │ Train/StopIter                 │ 1.0                    │
# │ Train/PolicyRatio/Mean         │ 1.0004843473434448     │
# │ Train/PolicyRatio/Min          │ 1.0004843473434448     │
# │ Train/PolicyRatio/Max          │ 1.0004843473434448     │
# │ Train/PolicyRatio/Std          │ 0.005768607370555401   │
# │ Train/LR                       │ 0.00029460000223480165 │
# │ Train/PolicyStd                │ 0.9957723021507263     │
# │ TotalEnvSteps                  │ 18432.0                │
# │ Loss/Loss_pi                   │ -0.0012792367488145828 │
# │ Loss/Loss_pi/Delta             │ 0.0007565068081021309  │
# │ Value/Adv                      │ 0.014522556215524673   │
# │ Loss/Loss_reward_critic        │ 3236.244384765625      │
# │ Loss/Loss_reward_critic/Delta  │ 279.504150390625       │
# │ Value/reward                   │ 6.616093635559082      │
# │ Loss/Loss_cost_critic          │ 15.194072723388672     │
# │ Loss/Loss_cost_critic/Delta    │ -3.9869327545166016    │
# │ Value/cost                     │ 5.018284320831299      │
# │ Time/Total                     │ 11.017265319824219     │
# │ Time/Rollout                   │ 1.1085469722747803     │
# │ Time/Update                    │ 0.0994272232055664     │
# │ Time/Epoch                     │ 1.207995891571045      │
# │ Time/FPS                       │ 1695.3699951171875     │
# │ Metrics/LagrangeMultiplier/Mea │ 0.3160792589187622     │
# │ Metrics/LagrangeMultiplier/Min │ 0.3160792589187622     │
# │ Metrics/LagrangeMultiplier/Max │ 0.3160792589187622     │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                    │
# └────────────────────────────────┴────────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 198.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                        ┃ Value                   ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                  │ 561.0756225585938       │
# │ Metrics/EpCost                 │ 63.10416793823242       │
# │ Metrics/EpLen                  │ 268.9375                │
# │ Train/Epoch                    │ 9.0                     │
# │ Train/Entropy                  │ 1.4151145219802856      │
# │ Train/KL                       │ 0.002473239554092288    │
# │ Train/StopIter                 │ 1.0                     │
# │ Train/PolicyRatio/Mean         │ 1.0005133152008057      │
# │ Train/PolicyRatio/Min          │ 1.0005133152008057      │
# │ Train/PolicyRatio/Max          │ 1.0005133152008057      │
# │ Train/PolicyRatio/Std          │ 0.005038109607994556    │
# │ Train/LR                       │ 0.00029399999766610563  │
# │ Train/PolicyStd                │ 0.9961836338043213      │
# │ TotalEnvSteps                  │ 20480.0                 │
# │ Loss/Loss_pi                   │ -0.00044691190123558044 │
# │ Loss/Loss_pi/Delta             │ 0.0008323248475790024   │
# │ Value/Adv                      │ 0.008349450305104256    │
# │ Loss/Loss_reward_critic        │ 3182.2333984375         │
# │ Loss/Loss_reward_critic/Delta  │ -54.010986328125        │
# │ Value/reward                   │ 6.5185723304748535      │
# │ Loss/Loss_cost_critic          │ 11.385025024414062      │
# │ Loss/Loss_cost_critic/Delta    │ -3.8090476989746094     │
# │ Value/cost                     │ 5.537253379821777       │
# │ Time/Total                     │ 12.266838073730469      │
# │ Time/Rollout                   │ 1.1439850330352783      │
# │ Time/Update                    │ 0.09705400466918945     │
# │ Time/Epoch                     │ 1.2410602569580078      │
# │ Time/FPS                       │ 1650.201904296875       │
# │ Metrics/LagrangeMultiplier/Mea │ 0.35210201144218445     │
# │ Metrics/LagrangeMultiplier/Min │ 0.35210201144218445     │
# │ Metrics/LagrangeMultiplier/Max │ 0.35210201144218445     │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                     │
# └────────────────────────────────┴─────────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 2048.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                        ┃ Value                 ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                  │ 561.0756225585938     │
# │ Metrics/EpCost                 │ 63.10416793823242     │
# │ Metrics/EpLen                  │ 268.9375              │
# │ Train/Epoch                    │ 10.0                  │
# │ Train/Entropy                  │ 1.4136857986450195    │
# │ Train/KL                       │ 0.004804249387234449  │
# │ Train/StopIter                 │ 1.0                   │
# │ Train/PolicyRatio/Mean         │ 1.0029457807540894    │
# │ Train/PolicyRatio/Min          │ 1.0029457807540894    │
# │ Train/PolicyRatio/Max          │ 1.0029457807540894    │
# │ Train/PolicyRatio/Std          │ 0.01369937602430582   │
# │ Train/LR                       │ 0.0002933999930974096 │
# │ Train/PolicyStd                │ 0.9947620630264282    │
# │ TotalEnvSteps                  │ 22528.0               │
# │ Loss/Loss_pi                   │ -0.005631706211715937 │
# │ Loss/Loss_pi/Delta             │ -0.005184794310480356 │
# │ Value/Adv                      │ -0.0770782083272934   │
# │ Loss/Loss_reward_critic        │ 3244.192138671875     │
# │ Loss/Loss_reward_critic/Delta  │ 61.958740234375       │
# │ Value/reward                   │ 8.218178749084473     │
# │ Loss/Loss_cost_critic          │ 29.15908432006836     │
# │ Loss/Loss_cost_critic/Delta    │ 17.774059295654297    │
# │ Value/cost                     │ 5.822818756103516     │
# │ Time/Total                     │ 13.477428436279297    │
# │ Time/Rollout                   │ 1.1046600341796875    │
# │ Time/Update                    │ 0.09759879112243652   │
# │ Time/Epoch                     │ 1.2022840976715088    │
# │ Time/FPS                       │ 1703.4256591796875    │
# │ Metrics/LagrangeMultiplier/Mea │ 0.38832637667655945   │
# │ Metrics/LagrangeMultiplier/Min │ 0.38832637667655945   │
# │ Metrics/LagrangeMultiplier/Max │ 0.38832637667655945   │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                   │
# └────────────────────────────────┴───────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 1892.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                        ┃ Value                  ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                  │ 556.7384643554688      │
# │ Metrics/EpCost                 │ 62.448978424072266     │
# │ Metrics/EpLen                  │ 266.6326599121094      │
# │ Train/Epoch                    │ 11.0                   │
# │ Train/Entropy                  │ 1.411158800125122      │
# │ Train/KL                       │ 0.005543236155062914   │
# │ Train/StopIter                 │ 1.0                    │
# │ Train/PolicyRatio/Mean         │ 0.9960713386535645     │
# │ Train/PolicyRatio/Min          │ 0.9960713386535645     │
# │ Train/PolicyRatio/Max          │ 0.9960713386535645     │
# │ Train/PolicyRatio/Std          │ 0.01078866422176361    │
# │ Train/LR                       │ 0.0002927999885287136  │
# │ Train/PolicyStd                │ 0.9922508001327515     │
# │ TotalEnvSteps                  │ 24576.0                │
# │ Loss/Loss_pi                   │ -0.0016213282942771912 │
# │ Loss/Loss_pi/Delta             │ 0.0040103779174387455  │
# │ Value/Adv                      │ 0.024607837200164795   │
# │ Loss/Loss_reward_critic        │ 3502.59423828125       │
# │ Loss/Loss_reward_critic/Delta  │ 258.402099609375       │
# │ Value/reward                   │ 9.568302154541016      │
# │ Loss/Loss_cost_critic          │ 17.72378158569336      │
# │ Loss/Loss_cost_critic/Delta    │ -11.435302734375       │
# │ Value/cost                     │ 6.773923873901367      │
# │ Time/Total                     │ 14.688886642456055     │
# │ Time/Rollout                   │ 1.1074891090393066     │
# │ Time/Update                    │ 0.0957939624786377     │
# │ Time/Epoch                     │ 1.2033069133758545     │
# │ Time/FPS                       │ 1701.9764404296875     │
# │ Metrics/LagrangeMultiplier/Mea │ 0.42468369007110596    │
# │ Metrics/LagrangeMultiplier/Min │ 0.42468369007110596    │
# │ Metrics/LagrangeMultiplier/Max │ 0.42468369007110596    │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                    │
# └────────────────────────────────┴────────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 623.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                        ┃ Value                 ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                  │ 616.689697265625      │
# │ Metrics/EpCost                 │ 62.97999954223633     │
# │ Metrics/EpLen                  │ 278.55999755859375    │
# │ Train/Epoch                    │ 12.0                  │
# │ Train/Entropy                  │ 1.4127888679504395    │
# │ Train/KL                       │ 0.002560986438766122  │
# │ Train/StopIter                 │ 1.0                   │
# │ Train/PolicyRatio/Mean         │ 0.9998993873596191    │
# │ Train/PolicyRatio/Min          │ 0.9998993873596191    │
# │ Train/PolicyRatio/Max          │ 0.9998993873596191    │
# │ Train/PolicyRatio/Std          │ 0.005157659761607647  │
# │ Train/LR                       │ 0.000292200013063848  │
# │ Train/PolicyStd                │ 0.9938693046569824    │
# │ TotalEnvSteps                  │ 26624.0               │
# │ Loss/Loss_pi                   │ 0.0017340891063213348 │
# │ Loss/Loss_pi/Delta             │ 0.003355417400598526  │
# │ Value/Adv                      │ -0.09302911907434464  │
# │ Loss/Loss_reward_critic        │ 3623.5810546875       │
# │ Loss/Loss_reward_critic/Delta  │ 120.98681640625       │
# │ Value/reward                   │ 10.009992599487305    │
# │ Loss/Loss_cost_critic          │ 11.42632007598877     │
# │ Loss/Loss_cost_critic/Delta    │ -6.29746150970459     │
# │ Value/cost                     │ 7.503747463226318     │
# │ Time/Total                     │ 15.980010032653809    │
# │ Time/Rollout                   │ 1.1527020931243896    │
# │ Time/Update                    │ 0.13031315803527832   │
# │ Time/Epoch                     │ 1.2830381393432617    │
# │ Time/FPS                       │ 1596.2127685546875    │
# │ Metrics/LagrangeMultiplier/Mea │ 0.46116775274276733   │
# │ Metrics/LagrangeMultiplier/Min │ 0.46116775274276733   │
# │ Metrics/LagrangeMultiplier/Max │ 0.46116775274276733   │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                   │
# └────────────────────────────────┴───────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 1252.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                        ┃ Value                 ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                  │ 666.8195190429688     │
# │ Metrics/EpCost                 │ 63.13999938964844     │
# │ Metrics/EpLen                  │ 290.05999755859375    │
# │ Train/Epoch                    │ 13.0                  │
# │ Train/Entropy                  │ 1.4129984378814697    │
# │ Train/KL                       │ 0.00928050559014082   │
# │ Train/StopIter                 │ 1.0                   │
# │ Train/PolicyRatio/Mean         │ 1.0025808811187744    │
# │ Train/PolicyRatio/Min          │ 1.0025808811187744    │
# │ Train/PolicyRatio/Max          │ 1.0025808811187744    │
# │ Train/PolicyRatio/Std          │ 0.013846738263964653  │
# │ Train/LR                       │ 0.000291600008495152  │
# │ Train/PolicyStd                │ 0.9940779209136963    │
# │ TotalEnvSteps                  │ 28672.0               │
# │ Loss/Loss_pi                   │ -0.002289603929966688 │
# │ Loss/Loss_pi/Delta             │ -0.004023693036288023 │
# │ Value/Adv                      │ -0.03608959913253784  │
# │ Loss/Loss_reward_critic        │ 3517.79736328125      │
# │ Loss/Loss_reward_critic/Delta  │ -105.78369140625      │
# │ Value/reward                   │ 10.991448402404785    │
# │ Loss/Loss_cost_critic          │ 19.75232696533203     │
# │ Loss/Loss_cost_critic/Delta    │ 8.326006889343262     │
# │ Value/cost                     │ 7.81908655166626      │
# │ Time/Total                     │ 17.207178115844727    │
# │ Time/Rollout                   │ 1.1196300983428955    │
# │ Time/Update                    │ 0.09923386573791504   │
# │ Time/Epoch                     │ 1.218886137008667     │
# │ Time/FPS                       │ 1680.2225341796875    │
# │ Metrics/LagrangeMultiplier/Mea │ 0.49775800108909607   │
# │ Metrics/LagrangeMultiplier/Min │ 0.49775800108909607   │
# │ Metrics/LagrangeMultiplier/Max │ 0.49775800108909607   │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                   │
# └────────────────────────────────┴───────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 2048.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                        ┃ Value                  ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                  │ 666.8195190429688      │
# │ Metrics/EpCost                 │ 63.13999938964844      │
# │ Metrics/EpLen                  │ 290.05999755859375     │
# │ Train/Epoch                    │ 14.0                   │
# │ Train/Entropy                  │ 1.4136161804199219     │
# │ Train/KL                       │ 0.009496305137872696   │
# │ Train/StopIter                 │ 1.0                    │
# │ Train/PolicyRatio/Mean         │ 0.9989849328994751     │
# │ Train/PolicyRatio/Min          │ 0.9989849328994751     │
# │ Train/PolicyRatio/Max          │ 0.9989849328994751     │
# │ Train/PolicyRatio/Std          │ 0.011694316752254963   │
# │ Train/LR                       │ 0.000291000003926456   │
# │ Train/PolicyStd                │ 0.9946920871734619     │
# │ TotalEnvSteps                  │ 30720.0                │
# │ Loss/Loss_pi                   │ -0.004167227074503899  │
# │ Loss/Loss_pi/Delta             │ -0.0018776231445372105 │
# │ Value/Adv                      │ -0.33560237288475037   │
# │ Loss/Loss_reward_critic        │ 3474.43359375          │
# │ Loss/Loss_reward_critic/Delta  │ -43.36376953125        │
# │ Value/reward                   │ 11.783366203308105     │
# │ Loss/Loss_cost_critic          │ 6.641552925109863      │
# │ Loss/Loss_cost_critic/Delta    │ -13.110774040222168    │
# │ Value/cost                     │ 8.157831192016602      │
# │ Time/Total                     │ 18.523284912109375     │
# │ Time/Rollout                   │ 1.1728990077972412     │
# │ Time/Update                    │ 0.13477301597595215    │
# │ Time/Epoch                     │ 1.3077061176300049     │
# │ Time/FPS                       │ 1566.1025390625        │
# │ Metrics/LagrangeMultiplier/Mea │ 0.5344306230545044     │
# │ Metrics/LagrangeMultiplier/Min │ 0.5344306230545044     │
# │ Metrics/LagrangeMultiplier/Max │ 0.5344306230545044     │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                    │
# └────────────────────────────────┴────────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 1619.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                        ┃ Value                  ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                  │ 697.4810791015625      │
# │ Metrics/EpCost                 │ 63.47999954223633      │
# │ Metrics/EpLen                  │ 297.6199951171875      │
# │ Train/Epoch                    │ 15.0                   │
# │ Train/Entropy                  │ 1.4120545387268066     │
# │ Train/KL                       │ 0.006300208158791065   │
# │ Train/StopIter                 │ 1.0                    │
# │ Train/PolicyRatio/Mean         │ 1.001282811164856      │
# │ Train/PolicyRatio/Min          │ 1.001282811164856      │
# │ Train/PolicyRatio/Max          │ 1.001282811164856      │
# │ Train/PolicyRatio/Std          │ 0.007193191442638636   │
# │ Train/LR                       │ 0.00029039999935775995 │
# │ Train/PolicyStd                │ 0.993141770362854      │
# │ TotalEnvSteps                  │ 32768.0                │
# │ Loss/Loss_pi                   │ 0.0007757442072033882  │
# │ Loss/Loss_pi/Delta             │ 0.004942971281707287   │
# │ Value/Adv                      │ 0.15411388874053955    │
# │ Loss/Loss_reward_critic        │ 3853.12109375          │
# │ Loss/Loss_reward_critic/Delta  │ 378.6875               │
# │ Value/reward                   │ 12.698307037353516     │
# │ Loss/Loss_cost_critic          │ 7.729237079620361      │
# │ Loss/Loss_cost_critic/Delta    │ 1.087684154510498      │
# │ Value/cost                     │ 8.065964698791504      │
# │ Time/Total                     │ 19.81427001953125      │
# │ Time/Rollout                   │ 1.1664230823516846     │
# │ Time/Update                    │ 0.11476397514343262    │
# │ Time/Epoch                     │ 1.2812111377716064     │
# │ Time/FPS                       │ 1598.489013671875      │
# │ Metrics/LagrangeMultiplier/Mea │ 0.5711829662322998     │
# │ Metrics/LagrangeMultiplier/Min │ 0.5711829662322998     │
# │ Metrics/LagrangeMultiplier/Max │ 0.5711829662322998     │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                    │
# └────────────────────────────────┴────────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 2048.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                        ┃ Value                  ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                  │ 697.4810791015625      │
# │ Metrics/EpCost                 │ 63.47999954223633      │
# │ Metrics/EpLen                  │ 297.6199951171875      │
# │ Train/Epoch                    │ 16.0                   │
# │ Train/Entropy                  │ 1.4103118181228638     │
# │ Train/KL                       │ 0.0058333128690719604  │
# │ Train/StopIter                 │ 1.0                    │
# │ Train/PolicyRatio/Mean         │ 1.0001566410064697     │
# │ Train/PolicyRatio/Min          │ 1.0001566410064697     │
# │ Train/PolicyRatio/Max          │ 1.0001566410064697     │
# │ Train/PolicyRatio/Std          │ 0.01129110250622034    │
# │ Train/LR                       │ 0.00028979999478906393 │
# │ Train/PolicyStd                │ 0.9914149045944214     │
# │ TotalEnvSteps                  │ 34816.0                │
# │ Loss/Loss_pi                   │ -0.004212288185954094  │
# │ Loss/Loss_pi/Delta             │ -0.004988032393157482  │
# │ Value/Adv                      │ 0.01816578395664692    │
# │ Loss/Loss_reward_critic        │ 3958.892333984375      │
# │ Loss/Loss_reward_critic/Delta  │ 105.771240234375       │
# │ Value/reward                   │ 13.680046081542969     │
# │ Loss/Loss_cost_critic          │ 14.566567420959473     │
# │ Loss/Loss_cost_critic/Delta    │ 6.837330341339111      │
# │ Value/cost                     │ 7.7998552322387695     │
# │ Time/Total                     │ 21.088150024414062     │
# │ Time/Rollout                   │ 1.1640989780426025     │
# │ Time/Update                    │ 0.0998382568359375     │
# │ Time/Epoch                     │ 1.2639610767364502     │
# │ Time/FPS                       │ 1620.3031005859375     │
# │ Metrics/LagrangeMultiplier/Mea │ 0.6079962849617004     │
# │ Metrics/LagrangeMultiplier/Min │ 0.6079962849617004     │
# │ Metrics/LagrangeMultiplier/Max │ 0.6079962849617004     │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                    │
# └────────────────────────────────┴────────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 633.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                        ┃ Value                  ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                  │ 798.073486328125       │
# │ Metrics/EpCost                 │ 64.0199966430664       │
# │ Metrics/EpLen                  │ 322.3599853515625      │
# │ Train/Epoch                    │ 17.0                   │
# │ Train/Entropy                  │ 1.4087849855422974     │
# │ Train/KL                       │ 0.005142853129655123   │
# │ Train/StopIter                 │ 1.0                    │
# │ Train/PolicyRatio/Mean         │ 1.0009781122207642     │
# │ Train/PolicyRatio/Min          │ 1.0009781122207642     │
# │ Train/PolicyRatio/Max          │ 1.0009781122207642     │
# │ Train/PolicyRatio/Std          │ 0.008309375494718552   │
# │ Train/LR                       │ 0.0002891999902203679  │
# │ Train/PolicyStd                │ 0.9899111390113831     │
# │ TotalEnvSteps                  │ 36864.0                │
# │ Loss/Loss_pi                   │ -0.0013083652593195438 │
# │ Loss/Loss_pi/Delta             │ 0.00290392292663455    │
# │ Value/Adv                      │ -0.1377183496952057    │
# │ Loss/Loss_reward_critic        │ 3958.98876953125       │
# │ Loss/Loss_reward_critic/Delta  │ 0.096435546875         │
# │ Value/reward                   │ 14.092203140258789     │
# │ Loss/Loss_cost_critic          │ 6.6380815505981445     │
# │ Loss/Loss_cost_critic/Delta    │ -7.928485870361328     │
# │ Value/cost                     │ 8.065053939819336      │
# │ Time/Total                     │ 22.4160213470459       │
# │ Time/Rollout                   │ 1.2080678939819336     │
# │ Time/Update                    │ 0.11146116256713867    │
# │ Time/Epoch                     │ 1.319554090499878      │
# │ Time/FPS                       │ 1552.0394287109375     │
# │ Metrics/LagrangeMultiplier/Mea │ 0.6448831558227539     │
# │ Metrics/LagrangeMultiplier/Min │ 0.6448831558227539     │
# │ Metrics/LagrangeMultiplier/Max │ 0.6448831558227539     │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                    │
# └────────────────────────────────┴────────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 195.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                        ┃ Value                  ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                  │ 938.6253662109375      │
# │ Metrics/EpCost                 │ 68.72000122070312      │
# │ Metrics/EpLen                  │ 357.6400146484375      │
# │ Train/Epoch                    │ 18.0                   │
# │ Train/Entropy                  │ 1.409166693687439      │
# │ Train/KL                       │ 0.00785361509770155    │
# │ Train/StopIter                 │ 1.0                    │
# │ Train/PolicyRatio/Mean         │ 0.9987689256668091     │
# │ Train/PolicyRatio/Min          │ 0.9987689256668091     │
# │ Train/PolicyRatio/Max          │ 0.9987689256668091     │
# │ Train/PolicyRatio/Std          │ 0.008150149136781693   │
# │ Train/LR                       │ 0.0002885999856516719  │
# │ Train/PolicyStd                │ 0.9902873635292053     │
# │ TotalEnvSteps                  │ 38912.0                │
# │ Loss/Loss_pi                   │ -0.0056474581360816956 │
# │ Loss/Loss_pi/Delta             │ -0.004339092876762152  │
# │ Value/Adv                      │ -0.10071933269500732   │
# │ Loss/Loss_reward_critic        │ 4023.03515625          │
# │ Loss/Loss_reward_critic/Delta  │ 64.04638671875         │
# │ Value/reward                   │ 14.863152503967285     │
# │ Loss/Loss_cost_critic          │ 20.07648277282715      │
# │ Loss/Loss_cost_critic/Delta    │ 13.438401222229004     │
# │ Value/cost                     │ 7.994677543640137      │
# │ Time/Total                     │ 23.722074508666992     │
# │ Time/Rollout                   │ 1.1794018745422363     │
# │ Time/Update                    │ 0.11741089820861816    │
# │ Time/Epoch                     │ 1.2968368530273438     │
# │ Time/FPS                       │ 1579.2286376953125     │
# │ Metrics/LagrangeMultiplier/Mea │ 0.6820563077926636     │
# │ Metrics/LagrangeMultiplier/Min │ 0.6820563077926636     │
# │ Metrics/LagrangeMultiplier/Max │ 0.6820563077926636     │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                    │
# └────────────────────────────────┴────────────────────────┘
# ...
# │ Loss/Loss_cost_critic/Delta    │ 0.05010513216257095    │
# │ Value/cost                     │ 0.1335776001214981     │
# │ Time/Total                     │ 631.3271484375         │
# │ Time/Rollout                   │ 1.2585599422454834     │
# │ Time/Update                    │ 0.11960196495056152    │
# │ Time/Epoch                     │ 1.3781919479370117     │
# │ Time/FPS                       │ 1486.0048828125        │
# │ Metrics/LagrangeMultiplier/Mea │ 11.642845153808594     │
# │ Metrics/LagrangeMultiplier/Min │ 11.642845153808594     │
# │ Metrics/LagrangeMultiplier/Max │ 11.642845153808594     │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                    │
# └────────────────────────────────┴────────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 2048.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                        ┃ Value                   ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                  │ 2995.366455078125       │
# │ Metrics/EpCost                 │ 41.84000015258789       │
# │ Metrics/EpLen                  │ 763.6799926757812       │
# │ Train/Epoch                    │ 494.0                   │
# │ Train/Entropy                  │ 1.2678056955337524      │
# │ Train/KL                       │ 4.169170551904244e-06   │
# │ Train/StopIter                 │ 1.0                     │
# │ Train/PolicyRatio/Mean         │ 0.9999401569366455      │
# │ Train/PolicyRatio/Min          │ 0.9999401569366455      │
# │ Train/PolicyRatio/Max          │ 0.9999401569366455      │
# │ Train/PolicyRatio/Std          │ 0.0002173326356569305   │
# │ Train/LR                       │ 3.000000106112566e-06   │
# │ Train/PolicyStd                │ 0.8607466220855713      │
# │ TotalEnvSteps                  │ 1013760.0               │
# │ Loss/Loss_pi                   │ -1.3390090316534042e-05 │
# │ Loss/Loss_pi/Delta             │ -1.4340388588607311e-05 │
# │ Value/Adv                      │ -0.12289705127477646    │
# │ Loss/Loss_reward_critic        │ 652.7193603515625       │
# │ Loss/Loss_reward_critic/Delta  │ -12.7373046875          │
# │ Value/reward                   │ 312.1859130859375       │
# │ Loss/Loss_cost_critic          │ 0.11082316935062408     │
# │ Loss/Loss_cost_critic/Delta    │ -0.0032609477639198303  │
# │ Value/cost                     │ 0.19743067026138306     │
# │ Time/Total                     │ 632.702880859375        │
# │ Time/Rollout                   │ 1.2693440914154053      │
# │ Time/Update                    │ 0.09702205657958984     │
# │ Time/Epoch                     │ 1.3663890361785889      │
# │ Time/FPS                       │ 1498.841064453125       │
# │ Metrics/LagrangeMultiplier/Mea │ 11.669082641601562      │
# │ Metrics/LagrangeMultiplier/Min │ 11.669082641601562      │
# │ Metrics/LagrangeMultiplier/Max │ 11.669082641601562      │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                     │
# └────────────────────────────────┴─────────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 2048.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                        ┃ Value                   ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                  │ 2995.366455078125       │
# │ Metrics/EpCost                 │ 41.84000015258789       │
# │ Metrics/EpLen                  │ 763.6799926757812       │
# │ Train/Epoch                    │ 495.0                   │
# │ Train/Entropy                  │ 1.267799973487854       │
# │ Train/KL                       │ 1.181718971565715e-06   │
# │ Train/StopIter                 │ 1.0                     │
# │ Train/PolicyRatio/Mean         │ 1.0000007152557373      │
# │ Train/PolicyRatio/Min          │ 1.0000007152557373      │
# │ Train/PolicyRatio/Max          │ 1.0000007152557373      │
# │ Train/PolicyRatio/Std          │ 9.978281013900414e-05   │
# │ Train/LR                       │ 2.4000000848900527e-06  │
# │ Train/PolicyStd                │ 0.8607418537139893      │
# │ TotalEnvSteps                  │ 1015808.0               │
# │ Loss/Loss_pi                   │ -1.5851110219955444e-06 │
# │ Loss/Loss_pi/Delta             │ 1.1804979294538498e-05  │
# │ Value/Adv                      │ -0.12761570513248444    │
# │ Loss/Loss_reward_critic        │ 650.7158813476562       │
# │ Loss/Loss_reward_critic/Delta  │ -2.00347900390625       │
# │ Value/reward                   │ 312.80975341796875      │
# │ Loss/Loss_cost_critic          │ 0.06759808957576752     │
# │ Loss/Loss_cost_critic/Delta    │ -0.04322507977485657    │
# │ Value/cost                     │ 0.16432982683181763     │
# │ Time/Total                     │ 634.099853515625        │
# │ Time/Rollout                   │ 1.237560749053955       │
# │ Time/Update                    │ 0.15077805519104004     │
# │ Time/Epoch                     │ 1.3883650302886963      │
# │ Time/FPS                       │ 1475.117431640625       │
# │ Metrics/LagrangeMultiplier/Mea │ 11.695335388183594      │
# │ Metrics/LagrangeMultiplier/Min │ 11.695335388183594      │
# │ Metrics/LagrangeMultiplier/Max │ 11.695335388183594      │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                     │
# └────────────────────────────────┴─────────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 2048.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                        ┃ Value                   ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                  │ 2995.366455078125       │
# │ Metrics/EpCost                 │ 41.84000015258789       │
# │ Metrics/EpLen                  │ 763.6799926757812       │
# │ Train/Epoch                    │ 496.0                   │
# │ Train/Entropy                  │ 1.267793893814087       │
# │ Train/KL                       │ 2.993479029100854e-07   │
# │ Train/StopIter                 │ 1.0                     │
# │ Train/PolicyRatio/Mean         │ 1.0000050067901611      │
# │ Train/PolicyRatio/Min          │ 1.0000050067901611      │
# │ Train/PolicyRatio/Max          │ 1.0000050067901611      │
# │ Train/PolicyRatio/Std          │ 4.03800695494283e-05    │
# │ Train/LR                       │ 1.7999999499807018e-06  │
# │ Train/PolicyStd                │ 0.8607367277145386      │
# │ TotalEnvSteps                  │ 1017856.0               │
# │ Loss/Loss_pi                   │ -1.0788789950311184e-06 │
# │ Loss/Loss_pi/Delta             │ 5.06232026964426e-07    │
# │ Value/Adv                      │ 0.09815482795238495     │
# │ Loss/Loss_reward_critic        │ 651.4364624023438       │
# │ Loss/Loss_reward_critic/Delta  │ 0.7205810546875         │
# │ Value/reward                   │ 313.43359375            │
# │ Loss/Loss_cost_critic          │ 0.08736112713813782     │
# │ Loss/Loss_cost_critic/Delta    │ 0.0197630375623703      │
# │ Value/cost                     │ 0.14062407612800598     │
# │ Time/Total                     │ 635.4077758789062       │
# │ Time/Rollout                   │ 1.2008001804351807      │
# │ Time/Update                    │ 0.09887504577636719     │
# │ Time/Epoch                     │ 1.2997009754180908      │
# │ Time/FPS                       │ 1575.7470703125         │
# │ Metrics/LagrangeMultiplier/Mea │ 11.721602439880371      │
# │ Metrics/LagrangeMultiplier/Min │ 11.721602439880371      │
# │ Metrics/LagrangeMultiplier/Max │ 11.721602439880371      │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                     │
# └────────────────────────────────┴─────────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 2048.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                        ┃ Value                  ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                  │ 2995.366455078125      │
# │ Metrics/EpCost                 │ 41.84000015258789      │
# │ Metrics/EpLen                  │ 763.6799926757812      │
# │ Train/Epoch                    │ 497.0                  │
# │ Train/Entropy                  │ 1.2677894830703735     │
# │ Train/KL                       │ 2.9454849936882965e-07 │
# │ Train/StopIter                 │ 1.0                    │
# │ Train/PolicyRatio/Mean         │ 1.000009298324585      │
# │ Train/PolicyRatio/Min          │ 1.000009298324585      │
# │ Train/PolicyRatio/Max          │ 1.000009298324585      │
# │ Train/PolicyRatio/Std          │ 6.251558079384267e-05  │
# │ Train/LR                       │ 1.2000000424450263e-06 │
# │ Train/PolicyStd                │ 0.8607333898544312     │
# │ TotalEnvSteps                  │ 1019904.0              │
# │ Loss/Loss_pi                   │ -4.83938492834568e-07  │
# │ Loss/Loss_pi/Delta             │ 5.949405021965504e-07  │
# │ Value/Adv                      │ 0.0018335338681936264  │
# │ Loss/Loss_reward_critic        │ 644.9081420898438      │
# │ Loss/Loss_reward_critic/Delta  │ -6.5283203125          │
# │ Value/reward                   │ 314.0574951171875      │
# │ Loss/Loss_cost_critic          │ 0.08362475037574768    │
# │ Loss/Loss_cost_critic/Delta    │ -0.0037363767623901367 │
# │ Value/cost                     │ 0.18143194913864136    │
# │ Time/Total                     │ 636.771728515625       │
# │ Time/Rollout                   │ 1.2191402912139893     │
# │ Time/Update                    │ 0.13648295402526855    │
# │ Time/Epoch                     │ 1.355647087097168      │
# │ Time/FPS                       │ 1510.71875             │
# │ Metrics/LagrangeMultiplier/Mea │ 11.747883796691895     │
# │ Metrics/LagrangeMultiplier/Min │ 11.747883796691895     │
# │ Metrics/LagrangeMultiplier/Max │ 11.747883796691895     │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                    │
# └────────────────────────────────┴────────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 2048.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                        ┃ Value                   ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                  │ 2995.366455078125       │
# │ Metrics/EpCost                 │ 41.84000015258789       │
# │ Metrics/EpLen                  │ 763.6799926757812       │
# │ Train/Epoch                    │ 498.0                   │
# │ Train/Entropy                  │ 1.2677860260009766      │
# │ Train/KL                       │ 1.5818432075320743e-07  │
# │ Train/StopIter                 │ 1.0                     │
# │ Train/PolicyRatio/Mean         │ 1.0000001192092896      │
# │ Train/PolicyRatio/Min          │ 1.0000001192092896      │
# │ Train/PolicyRatio/Max          │ 1.0000001192092896      │
# │ Train/PolicyRatio/Std          │ 2.5984754756791517e-05  │
# │ Train/LR                       │ 6.000000212225132e-07   │
# │ Train/PolicyStd                │ 0.8607304692268372      │
# │ TotalEnvSteps                  │ 1021952.0               │
# │ Loss/Loss_pi                   │ -7.499475032091141e-07  │
# │ Loss/Loss_pi/Delta             │ -2.6600901037454605e-07 │
# │ Value/Adv                      │ -0.015214294195175171   │
# │ Loss/Loss_reward_critic        │ 640.2183837890625       │
# │ Loss/Loss_reward_critic/Delta  │ -4.68975830078125       │
# │ Value/reward                   │ 314.681396484375        │
# │ Loss/Loss_cost_critic          │ 0.1374770998954773      │
# │ Loss/Loss_cost_critic/Delta    │ 0.053852349519729614    │
# │ Value/cost                     │ 0.17155081033706665     │
# │ Time/Total                     │ 638.2683715820312       │
# │ Time/Rollout                   │ 1.3066558837890625      │
# │ Time/Update                    │ 0.1806340217590332      │
# │ Time/Epoch                     │ 1.4873149394989014      │
# │ Time/FPS                       │ 1376.9791259765625      │
# │ Metrics/LagrangeMultiplier/Mea │ 11.77418041229248       │
# │ Metrics/LagrangeMultiplier/Min │ 11.77418041229248       │
# │ Metrics/LagrangeMultiplier/Max │ 11.77418041229248       │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                     │
# └────────────────────────────────┴─────────────────────────┘
# Warning: trajectory cut off when rollout by epoch at 2048.0 steps.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metrics                        ┃ Value                  ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Metrics/EpRet                  │ 2995.366455078125      │
# │ Metrics/EpCost                 │ 41.84000015258789      │
# │ Metrics/EpLen                  │ 763.6799926757812      │
# │ Train/Epoch                    │ 499.0                  │
# │ Train/Entropy                  │ 1.2677841186523438     │
# │ Train/KL                       │ 6.617824510612991e-09  │
# │ Train/StopIter                 │ 1.0                    │
# │ Train/PolicyRatio/Mean         │ 1.000006079673767      │
# │ Train/PolicyRatio/Min          │ 1.000006079673767      │
# │ Train/PolicyRatio/Max          │ 1.000006079673767      │
# │ Train/PolicyRatio/Std          │ 1.6295292880386114e-05 │
# │ Train/LR                       │ 0.0                    │
# │ Train/PolicyStd                │ 0.8607288002967834     │
# │ TotalEnvSteps                  │ 1024000.0              │
# │ Loss/Loss_pi                   │ 1.1723022907972336e-07 │
# │ Loss/Loss_pi/Delta             │ 8.671777322888374e-07  │
# │ Value/Adv                      │ 0.11411034315824509    │
# │ Loss/Loss_reward_critic        │ 639.453125             │
# │ Loss/Loss_reward_critic/Delta  │ -0.7652587890625       │
# │ Value/reward                   │ 315.30523681640625     │
# │ Loss/Loss_cost_critic          │ 0.06615722924470901    │
# │ Loss/Loss_cost_critic/Delta    │ -0.07131987065076828   │
# │ Value/cost                     │ 0.19826774299144745    │
# │ Time/Total                     │ 639.630615234375       │
# │ Time/Rollout                   │ 1.232733964920044      │
# │ Time/Update                    │ 0.12024807929992676    │
# │ Time/Epoch                     │ 1.3530068397521973     │
# │ Time/FPS                       │ 1513.6656494140625     │
# │ Metrics/LagrangeMultiplier/Mea │ 11.800491333007812     │
# │ Metrics/LagrangeMultiplier/Min │ 11.800491333007812     │
# │ Metrics/LagrangeMultiplier/Max │ 11.800491333007812     │
# │ Metrics/LagrangeMultiplier/Std │ 0.0                    │
# └────────────────────────────────┴────────────────────────┘
# (2995.366455078125, 41.84000015258789, 763.6799926757812)
